# %% [markdown]
# # 1. Keypoints using MP Holistic

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp


mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities


def mediapipe_detection(img, mp_model):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # BGR → RGB
    img.flags.writeable = False                  # Disable writeability of img
    results = mp_model.process(img)                 # Obtain landmarks from frame
    img.flags.writeable = True                   # Re-enable writeability of img
    img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR) # RGB → BGR
    return img, results


def draw_landmarks(img, results):
    mp_drawing.draw_landmarks(img, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS)               # Draw Left hand connections
    mp_drawing.draw_landmarks(img, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)              # Draw Right hand connections
    mp_drawing.draw_landmarks(img, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION,                # Draw Face connections
                              mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),      # Change color so it differs
                              mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)) 
    mp_drawing.draw_landmarks(img, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS)                    # Draw Pose connections


def extract_keypoints(results):
    # Extract Pose Landmarks
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    # Extract Face Landmarks
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    # Extract left and right Hand Landmarks separately
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %% [markdown]
# # 2. Setup Folders for Collection

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('data')

# Actions we want to detect
actions = np.array(['hello', 'thanks', 'iloveyou', 'help', 'please', 'father', 'mother']) 

# 30 videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# %%
# Create empty folders for each action and within them empty folders for each (in total 30) sequence
# Inside each of these folders, we will locate the 30 .npy files corresponding to each frame
for action in actions: 
    # dirmax = np.max(np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int))
    dirmax = -1
    for sequence in range(1,no_sequences+1):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(dirmax+sequence)))
        except:
            pass

# %% [markdown]
# # 3. Collect Keypoint Values for Training and Testing

# %%
cap = cv2.VideoCapture(0)   # This will allow us to access the camera in real time
breakk = 0                  # This mousketool will be useful later for ending the loop

# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # Loop through actions
    for action in actions:
        # Loop through videos
        for sequence in range(no_sequences):
            # Loop through video length (30 frames)
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Extract landmarks
                img, results = mediapipe_detection(frame, holistic)

                # Draw landmarks
                draw_landmarks(img, results)
                
                if frame_num == 0: 
                    cv2.putText(img, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(img, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', img)
                    cv2.waitKey(2000)
                else: 
                    cv2.putText(img, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', img)
                
                # Export keypoints as .npy
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence + 0), str(frame_num))  # Just change the + 10
                np.save(npy_path, keypoints)

                # Break with "Esc"
                if cv2.waitKey(10) & 0xFF == 27:
                    breakk = 1
                    break
            
            if breakk ==1:
                break
        
        if breakk ==1:
            break
                    
    cap.release()
    cv2.destroyAllWindows()

# %% [markdown]
# # 3.1. Data Augmentation by Mirroring w.r.t X Axis

# %%
def mirr_kps(keypoints_vector):
    # Split the keypoints vector into two parts: one with 4 arguments (x, y, z, visibility) and one with 3 arguments (x, y, z)
    keypoints_4d = keypoints_vector[:33 * 4]
    keypoints_3d = keypoints_vector[33 * 4:]
    
    # Reshape into a 2D array with four columns (x, y, z, visibility) or 3 columns (x, y, z)
    keypoints_4d_2d = keypoints_4d.reshape(-1, 4)
    keypoints_3d_2d = keypoints_3d.reshape(-1, 3)

    # Find indices where x-coordinate is not equal to 0
    nonzero_x_indices_4d = np.where(keypoints_4d_2d[:, 0] != 0)[0]
    nonzero_x_indices_3d = np.where(keypoints_3d_2d[:, 0] != 0)[0]
    
    # Negate the x-coordinates of the keypoints in both parts where x is not 0
    keypoints_4d_2d[nonzero_x_indices_4d, 0] = 1-keypoints_4d_2d[nonzero_x_indices_4d, 0]
    keypoints_3d_2d[nonzero_x_indices_3d, 0] = 1-keypoints_3d_2d[nonzero_x_indices_3d, 0]
    
    # Reshape both parts back into 1D vectors
    mirrored_keypoints_4d = keypoints_4d_2d.flatten()
    mirrored_keypoints_3d = keypoints_3d_2d.flatten()
    
    # Concatenate the two parts back into a single 1D vector
    mirrored_keypoints_vector = np.concatenate([mirrored_keypoints_4d, mirrored_keypoints_3d])
    
    return mirrored_keypoints_vector

# %%
# Mirror datasets and add folders (each sequence with the resulting 30 frames) in the action folder
for action in actions:
    dirmax = np.max(np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int))
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence+dirmax+1)))
        except:
            pass
        for frame_num in range(sequence_length):
            kps = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            mirr = mirr_kps(kps)
            npy_path = os.path.join(DATA_PATH, action, str(sequence+30), str(frame_num))  # Just change the + 30
            np.save(npy_path, mirr)

# %% [markdown]
# # 4. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

label_mapa = {label:num for num, label in enumerate(actions)}

sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        # Join all frames per sequence in "window"
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_mapa[action])

X = np.array(sequences)
y = to_categorical(labels).astype(int)
# Split dataset in train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %% [markdown]
# # 5. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.optimizers import Adam

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
# We need return sequences in the first LSTM layers because that info will input the following LSTM
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
# Last LSTM layer won't need a return sequence since it goes directly to fc layers
model.add(LSTM(64, return_sequences=False, activation='relu'))
# We reduce the width of the layer to finally the output representing each class (action)
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

optimizer = Adam(lr=5e-6)  # You can experiment with different learning rates, we use the other predetermined values
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
# del model

# %%
model.fit(X_train, y_train, epochs=150, callbacks=[tb_callback])
# Out:
# Epoch 1/150
# 12/12 [==============================] - 4s 94ms/step - loss: 1.9447 - categorical_accuracy: 0.1082
# Epoch 2/150
# 12/12 [==============================] - 1s 49ms/step - loss: 1.9425 - categorical_accuracy: 0.1451
# Epoch 3/150
# 12/12 [==============================] - 1s 47ms/step - loss: 1.9416 - categorical_accuracy: 0.1842
# Epoch 4/150
# 12/12 [==============================] - 1s 51ms/step - loss: 1.9416 - categorical_accuracy: 0.1834
# Epoch 5/150
# 12/12 [==============================] - 1s 50ms/step - loss: 1.9390 - categorical_accuracy: 0.1963
# Epoch 6/150
# 12/12 [==============================] - 1s 50ms/step - loss: 1.9361 - categorical_accuracy: 0.1902
# Epoch 7/150
# 12/12 [==============================] - 1s 57ms/step - loss: 1.9355 - categorical_accuracy: 0.1797
# Epoch 8/150
# 12/12 [==============================] - 1s 55ms/step - loss: 1.9309 - categorical_accuracy: 0.1989
# Epoch 9/150
# 12/12 [==============================] - 1s 52ms/step - loss: 1.9283 - categorical_accuracy: 0.2010
# Epoch 10/150
# 12/12 [==============================] - 1s 52ms/step - loss: 1.9295 - categorical_accuracy: 0.1775
# Epoch 11/150
# 12/12 [==============================] - 1s 53ms/step - loss: 1.9253 - categorical_accuracy: 0.1881
# Epoch 12/150
# 12/12 [==============================] - 1s 50ms/step - loss: 1.9255 - categorical_accuracy: 0.1873
# Epoch 13/150
# 12/12 [==============================] - 1s 47ms/step - loss: 1.9211 - categorical_accuracy: 0.1899
# Epoch 14/150
# 12/12 [==============================] - 1s 47ms/step - loss: 1.9158 - categorical_accuracy: 0.1774
# Epoch 15/150
# 12/12 [==============================] - 1s 47ms/step - loss: 1.9021 - categorical_accuracy: 0.2027
# Epoch 16/150
# 12/12 [==============================] - 1s 47ms/step - loss: 1.8917 - categorical_accuracy: 0.1853
# Epoch 17/150
# 12/12 [==============================] - 1s 48ms/step - loss: 1.8647 - categorical_accuracy: 0.1756
# Epoch 18/150
# 12/12 [==============================] - 1s 47ms/step - loss: 1.8479 - categorical_accuracy: 0.1810
# Epoch 19/150
# 12/12 [==============================] - 1s 48ms/step - loss: 1.8198 - categorical_accuracy: 0.2078
# Epoch 20/150
# 12/12 [==============================] - 1s 47ms/step - loss: 1.7948 - categorical_accuracy: 0.2063
# Epoch 21/150
# 12/12 [==============================] - 1s 49ms/step - loss: 1.7973 - categorical_accuracy: 0.2269
# Epoch 22/150
# 12/12 [==============================] - 1s 51ms/step - loss: 1.7733 - categorical_accuracy: 0.2161
# Epoch 23/150
# 12/12 [==============================] - 1s 53ms/step - loss: 1.7853 - categorical_accuracy: 0.2206
# Epoch 24/150
# 12/12 [==============================] - 1s 53ms/step - loss: 1.7878 - categorical_accuracy: 0.2241
# Epoch 25/150
# 12/12 [==============================] - 1s 50ms/step - loss: 1.7196 - categorical_accuracy: 0.2699
# Epoch 26/150
# 12/12 [==============================] - 1s 52ms/step - loss: 1.7275 - categorical_accuracy: 0.2846
# Epoch 27/150
# 12/12 [==============================] - 1s 54ms/step - loss: 1.7374 - categorical_accuracy: 0.2770
# Epoch 28/150
# 12/12 [==============================] - 1s 52ms/step - loss: 1.7169 - categorical_accuracy: 0.2985
# Epoch 29/150
# 12/12 [==============================] - 1s 57ms/step - loss: 1.6888 - categorical_accuracy: 0.3184
# Epoch 30/150
# 12/12 [==============================] - 1s 50ms/step - loss: 1.7199 - categorical_accuracy: 0.2810
# Epoch 31/150
# 12/12 [==============================] - 1s 50ms/step - loss: 1.6925 - categorical_accuracy: 0.3195
# Epoch 32/150
# 12/12 [==============================] - 1s 49ms/step - loss: 1.6617 - categorical_accuracy: 0.3065
# Epoch 33/150
# 12/12 [==============================] - 1s 48ms/step - loss: 1.6260 - categorical_accuracy: 0.3055
# Epoch 34/150
# 12/12 [==============================] - 1s 49ms/step - loss: 1.6529 - categorical_accuracy: 0.3137
# Epoch 35/150
# 12/12 [==============================] - 1s 49ms/step - loss: 1.6845 - categorical_accuracy: 0.2866
# Epoch 36/150
# 12/12 [==============================] - 1s 48ms/step - loss: 1.6628 - categorical_accuracy: 0.2873
# Epoch 37/150
# 12/12 [==============================] - 1s 48ms/step - loss: 1.6207 - categorical_accuracy: 0.3164
# Epoch 38/150
# 12/12 [==============================] - 1s 47ms/step - loss: 1.5711 - categorical_accuracy: 0.3703
# Epoch 39/150
# 12/12 [==============================] - 1s 51ms/step - loss: 1.6352 - categorical_accuracy: 0.2967
# Epoch 40/150
# 12/12 [==============================] - 1s 50ms/step - loss: 1.5693 - categorical_accuracy: 0.3543
# Epoch 41/150
# 12/12 [==============================] - 1s 52ms/step - loss: 1.5935 - categorical_accuracy: 0.2916
# Epoch 42/150
# 12/12 [==============================] - 1s 49ms/step - loss: 1.6236 - categorical_accuracy: 0.3071
# Epoch 43/150
# 12/12 [==============================] - 1s 48ms/step - loss: 1.5927 - categorical_accuracy: 0.2809
# Epoch 44/150
# 12/12 [==============================] - 1s 46ms/step - loss: 1.5749 - categorical_accuracy: 0.2891
# Epoch 45/150
# 12/12 [==============================] - 1s 46ms/step - loss: 1.5282 - categorical_accuracy: 0.3852
# Epoch 46/150
# 12/12 [==============================] - 1s 47ms/step - loss: 1.5453 - categorical_accuracy: 0.3480
# Epoch 47/150
# 12/12 [==============================] - 1s 48ms/step - loss: 1.5362 - categorical_accuracy: 0.3451
# Epoch 48/150
# 12/12 [==============================] - 1s 49ms/step - loss: 1.5097 - categorical_accuracy: 0.3598
# Epoch 49/150
# 12/12 [==============================] - 1s 47ms/step - loss: 1.4956 - categorical_accuracy: 0.3561
# Epoch 50/150
# 12/12 [==============================] - 1s 50ms/step - loss: 1.4854 - categorical_accuracy: 0.3656
# Epoch 51/150
# 12/12 [==============================] - 1s 47ms/step - loss: 1.4721 - categorical_accuracy: 0.3890
# Epoch 52/150
# 12/12 [==============================] - 1s 52ms/step - loss: 1.4872 - categorical_accuracy: 0.3845
# Epoch 53/150
# 12/12 [==============================] - 1s 54ms/step - loss: 1.4476 - categorical_accuracy: 0.3970
# Epoch 54/150
# 12/12 [==============================] - 1s 53ms/step - loss: 1.4242 - categorical_accuracy: 0.4183
# Epoch 55/150
# 12/12 [==============================] - 1s 53ms/step - loss: 1.4180 - categorical_accuracy: 0.3846
# Epoch 56/150
# 12/12 [==============================] - 1s 53ms/step - loss: 1.4190 - categorical_accuracy: 0.4160
# Epoch 57/150
# 12/12 [==============================] - 1s 55ms/step - loss: 1.3681 - categorical_accuracy: 0.4298
# Epoch 58/150
# 12/12 [==============================] - 1s 53ms/step - loss: 1.4159 - categorical_accuracy: 0.4304
# Epoch 59/150
# 12/12 [==============================] - 1s 54ms/step - loss: 1.3902 - categorical_accuracy: 0.4559
# Epoch 60/150
# 12/12 [==============================] - 1s 48ms/step - loss: 1.3802 - categorical_accuracy: 0.4404
# Epoch 61/150
# 12/12 [==============================] - 1s 48ms/step - loss: 1.2993 - categorical_accuracy: 0.4619
# Epoch 62/150
# 12/12 [==============================] - 1s 48ms/step - loss: 1.3002 - categorical_accuracy: 0.5012
# Epoch 63/150
# 12/12 [==============================] - 1s 47ms/step - loss: 1.3772 - categorical_accuracy: 0.4719
# Epoch 64/150
# 12/12 [==============================] - 1s 51ms/step - loss: 1.2640 - categorical_accuracy: 0.4876
# Epoch 65/150
# 12/12 [==============================] - 1s 50ms/step - loss: 1.2609 - categorical_accuracy: 0.5311
# Epoch 66/150
# 12/12 [==============================] - 1s 45ms/step - loss: 1.2030 - categorical_accuracy: 0.5376
# Epoch 67/150
# 12/12 [==============================] - 1s 47ms/step - loss: 1.2625 - categorical_accuracy: 0.5540
# Epoch 68/150
# 12/12 [==============================] - 1s 46ms/step - loss: 1.2820 - categorical_accuracy: 0.5309
# Epoch 69/150
# 12/12 [==============================] - 1s 47ms/step - loss: 1.2069 - categorical_accuracy: 0.5568
# Epoch 70/150
# 12/12 [==============================] - 1s 50ms/step - loss: 1.2361 - categorical_accuracy: 0.5387
# Epoch 71/150
# 12/12 [==============================] - 1s 50ms/step - loss: 1.2090 - categorical_accuracy: 0.5655
# Epoch 72/150
# 12/12 [==============================] - 1s 54ms/step - loss: 1.1709 - categorical_accuracy: 0.5836
# Epoch 73/150
# 12/12 [==============================] - 1s 48ms/step - loss: 1.1351 - categorical_accuracy: 0.5803
# Epoch 74/150
# 12/12 [==============================] - 1s 48ms/step - loss: 1.1667 - categorical_accuracy: 0.5991
# Epoch 75/150
# 12/12 [==============================] - 1s 48ms/step - loss: 1.0725 - categorical_accuracy: 0.6193
# Epoch 76/150
# 12/12 [==============================] - 1s 43ms/step - loss: 1.0887 - categorical_accuracy: 0.6343
# Epoch 77/150
# 12/12 [==============================] - 1s 45ms/step - loss: 1.1548 - categorical_accuracy: 0.6098
# Epoch 78/150
# 12/12 [==============================] - 1s 45ms/step - loss: 1.1021 - categorical_accuracy: 0.5823
# Epoch 79/150
# 12/12 [==============================] - 1s 45ms/step - loss: 1.1191 - categorical_accuracy: 0.6058
# Epoch 80/150
# 12/12 [==============================] - 1s 45ms/step - loss: 1.0384 - categorical_accuracy: 0.6176
# Epoch 81/150
# 12/12 [==============================] - 1s 44ms/step - loss: 1.0084 - categorical_accuracy: 0.6441
# Epoch 82/150
# 12/12 [==============================] - 1s 45ms/step - loss: 1.0428 - categorical_accuracy: 0.6261
# Epoch 83/150
# 12/12 [==============================] - 1s 45ms/step - loss: 0.9702 - categorical_accuracy: 0.6608
# Epoch 84/150
# 12/12 [==============================] - 1s 44ms/step - loss: 0.8966 - categorical_accuracy: 0.6506
# Epoch 85/150
# 12/12 [==============================] - 1s 46ms/step - loss: 0.9473 - categorical_accuracy: 0.6537
# Epoch 86/150
# 12/12 [==============================] - 1s 51ms/step - loss: 0.9775 - categorical_accuracy: 0.6137
# Epoch 87/150
# 12/12 [==============================] - 1s 49ms/step - loss: 0.8671 - categorical_accuracy: 0.6872
# Epoch 88/150
# 12/12 [==============================] - 1s 51ms/step - loss: 0.8597 - categorical_accuracy: 0.6829
# Epoch 89/150
# 12/12 [==============================] - 1s 48ms/step - loss: 0.8582 - categorical_accuracy: 0.6620
# Epoch 90/150
# 12/12 [==============================] - 1s 44ms/step - loss: 0.8793 - categorical_accuracy: 0.6787
# Epoch 91/150
# 12/12 [==============================] - 1s 43ms/step - loss: 0.8114 - categorical_accuracy: 0.6986
# Epoch 92/150
# 12/12 [==============================] - 1s 44ms/step - loss: 0.7476 - categorical_accuracy: 0.7360
# Epoch 93/150
# 12/12 [==============================] - 1s 46ms/step - loss: 0.7946 - categorical_accuracy: 0.7166
# Epoch 94/150
# 12/12 [==============================] - 1s 45ms/step - loss: 0.7886 - categorical_accuracy: 0.6912
# Epoch 95/150
# 12/12 [==============================] - 1s 45ms/step - loss: 0.7257 - categorical_accuracy: 0.7371
# Epoch 96/150
# 12/12 [==============================] - 1s 45ms/step - loss: 0.7721 - categorical_accuracy: 0.7342
# Epoch 97/150
# 12/12 [==============================] - 1s 48ms/step - loss: 0.6738 - categorical_accuracy: 0.7857
# Epoch 98/150
# 12/12 [==============================] - 1s 50ms/step - loss: 0.8088 - categorical_accuracy: 0.7056
# Epoch 99/150
# 12/12 [==============================] - 1s 48ms/step - loss: 0.6342 - categorical_accuracy: 0.7615
# Epoch 100/150
# 12/12 [==============================] - 1s 53ms/step - loss: 0.6706 - categorical_accuracy: 0.7618
# Epoch 101/150
# 12/12 [==============================] - 1s 49ms/step - loss: 0.6652 - categorical_accuracy: 0.7698
# Epoch 102/150
# 12/12 [==============================] - 1s 47ms/step - loss: 0.6169 - categorical_accuracy: 0.7840
# Epoch 103/150
# 12/12 [==============================] - 1s 49ms/step - loss: 0.6718 - categorical_accuracy: 0.7641
# Epoch 104/150
# 12/12 [==============================] - 1s 48ms/step - loss: 0.5939 - categorical_accuracy: 0.8077
# Epoch 105/150
# 12/12 [==============================] - 1s 49ms/step - loss: 0.6228 - categorical_accuracy: 0.7994
# Epoch 106/150
# 12/12 [==============================] - 1s 46ms/step - loss: 0.6093 - categorical_accuracy: 0.8145
# Epoch 107/150
# 12/12 [==============================] - 1s 44ms/step - loss: 0.5993 - categorical_accuracy: 0.7724
# Epoch 108/150
# 12/12 [==============================] - 1s 44ms/step - loss: 0.5799 - categorical_accuracy: 0.7980
# Epoch 109/150
# 12/12 [==============================] - 1s 48ms/step - loss: 0.5969 - categorical_accuracy: 0.8051
# Epoch 110/150
# 12/12 [==============================] - 1s 47ms/step - loss: 0.5663 - categorical_accuracy: 0.8315
# Epoch 111/150
# 12/12 [==============================] - 1s 45ms/step - loss: 0.6539 - categorical_accuracy: 0.7875
# Epoch 112/150
# 12/12 [==============================] - 1s 44ms/step - loss: 0.6005 - categorical_accuracy: 0.8026
# Epoch 113/150
# 12/12 [==============================] - 1s 44ms/step - loss: 0.5036 - categorical_accuracy: 0.8409
# Epoch 114/150
# 12/12 [==============================] - 1s 47ms/step - loss: 0.5170 - categorical_accuracy: 0.8511
# Epoch 115/150
# 12/12 [==============================] - 1s 50ms/step - loss: 0.4966 - categorical_accuracy: 0.8568
# Epoch 116/150
# 12/12 [==============================] - 1s 48ms/step - loss: 0.5067 - categorical_accuracy: 0.8379
# Epoch 117/150
# 12/12 [==============================] - 1s 48ms/step - loss: 0.4849 - categorical_accuracy: 0.8704
# Epoch 118/150
# 12/12 [==============================] - 1s 48ms/step - loss: 0.5180 - categorical_accuracy: 0.8557
# Epoch 119/150
# 12/12 [==============================] - 1s 47ms/step - loss: 0.4688 - categorical_accuracy: 0.8691
# Epoch 120/150
# 12/12 [==============================] - 1s 45ms/step - loss: 0.4325 - categorical_accuracy: 0.8866
# Epoch 121/150
# 12/12 [==============================] - 1s 45ms/step - loss: 0.4493 - categorical_accuracy: 0.8485
# Epoch 122/150
# 12/12 [==============================] - 1s 45ms/step - loss: 0.4012 - categorical_accuracy: 0.8935
# Epoch 123/150
# 12/12 [==============================] - 1s 45ms/step - loss: 0.3841 - categorical_accuracy: 0.8996
# Epoch 124/150
# 12/12 [==============================] - 1s 44ms/step - loss: 0.3984 - categorical_accuracy: 0.8930
# Epoch 125/150
# 12/12 [==============================] - 1s 46ms/step - loss: 0.4251 - categorical_accuracy: 0.8676
# Epoch 126/150
# 12/12 [==============================] - 1s 46ms/step - loss: 0.3797 - categorical_accuracy: 0.8852
# Epoch 127/150
# 12/12 [==============================] - 1s 47ms/step - loss: 0.4194 - categorical_accuracy: 0.8684
# Epoch 128/150
# 12/12 [==============================] - 1s 51ms/step - loss: 0.3661 - categorical_accuracy: 0.8788
# Epoch 129/150
# 12/12 [==============================] - 1s 49ms/step - loss: 0.3823 - categorical_accuracy: 0.8904
# Epoch 130/150
# 12/12 [==============================] - 1s 50ms/step - loss: 0.4692 - categorical_accuracy: 0.8484
# Epoch 131/150
# 12/12 [==============================] - 1s 51ms/step - loss: 0.4826 - categorical_accuracy: 0.8519
# Epoch 132/150
# 12/12 [==============================] - 1s 51ms/step - loss: 0.4913 - categorical_accuracy: 0.8290
# Epoch 133/150
# 12/12 [==============================] - 1s 45ms/step - loss: 0.4382 - categorical_accuracy: 0.8737
# Epoch 134/150
# 12/12 [==============================] - 1s 47ms/step - loss: 0.3727 - categorical_accuracy: 0.8756
# Epoch 135/150
# 12/12 [==============================] - 1s 46ms/step - loss: 0.3462 - categorical_accuracy: 0.8844
# Epoch 136/150
# 12/12 [==============================] - 1s 50ms/step - loss: 0.3287 - categorical_accuracy: 0.9164
# Epoch 137/150
# 12/12 [==============================] - 1s 45ms/step - loss: 0.3400 - categorical_accuracy: 0.9065
# Epoch 138/150
# 12/12 [==============================] - 1s 45ms/step - loss: 0.3643 - categorical_accuracy: 0.8784
# Epoch 139/150
# 12/12 [==============================] - 1s 49ms/step - loss: 0.2960 - categorical_accuracy: 0.9210
# Epoch 140/150
# 12/12 [==============================] - 1s 48ms/step - loss: 0.2866 - categorical_accuracy: 0.9203
# Epoch 141/150
# 12/12 [==============================] - 1s 47ms/step - loss: 0.3093 - categorical_accuracy: 0.9354
# Epoch 142/150
# 12/12 [==============================] - 1s 55ms/step - loss: 0.2701 - categorical_accuracy: 0.9299
# Epoch 143/150
# 12/12 [==============================] - 1s 55ms/step - loss: 0.2695 - categorical_accuracy: 0.9221
# Epoch 144/150
# 12/12 [==============================] - 1s 51ms/step - loss: 0.2720 - categorical_accuracy: 0.9404
# Epoch 145/150
# 12/12 [==============================] - 1s 49ms/step - loss: 0.3000 - categorical_accuracy: 0.9188
# Epoch 146/150
# 12/12 [==============================] - 1s 49ms/step - loss: 0.2850 - categorical_accuracy: 0.9341
# Epoch 147/150
# 12/12 [==============================] - 1s 53ms/step - loss: 0.2401 - categorical_accuracy: 0.9474
# Epoch 148/150
# 12/12 [==============================] - 1s 48ms/step - loss: 0.2600 - categorical_accuracy: 0.9204
# Epoch 149/150
# 12/12 [==============================] - 1s 51ms/step - loss: 0.2651 - categorical_accuracy: 0.9363
# Epoch 150/150
# 12/12 [==============================] - 1s 47ms/step - loss: 0.2303 - categorical_accuracy: 0.9371

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 30, 64)            442112
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 30, 128)           98816
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 596,807
# Trainable params: 596,807
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %tensorboard --log_dir logs

# %% [markdown]
# # 6. Save / Load Weights

# %%
model.save('actions_model.h5')

# %%
model.load_weights('actions_model.h5')

# %% [markdown]
# # 7. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score



yhat = model.predict(X_test)                # Can replace with X_train

ytrue = np.argmax(y_test, axis=1).tolist()  # Can replace with y_train
yhat = np.argmax(yhat, axis=1).tolist()

multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[35,  1],
#         [ 0,  6]],
#
#        [[38,  1],
#         [ 0,  3]],
#
#        [[34,  0],
#         [ 0,  8]],
#
#        [[31,  0],
#         [ 0, 11]],
#
#        [[37,  0],
#         [ 0,  5]],
#
#        [[37,  0],
#         [ 1,  4]],
#
#        [[38,  0],
#         [ 1,  3]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.9523809523809523

# %% [markdown]
# # 8. Test in Real Time

# %%
from scipy import stats

# Different colors for each action
colors = [(255, 0, 0), (0, 255, 0), (0, 0, 255), (255, 255, 0), (255, 0, 255), (0, 255, 255), (128, 128, 128)]
# Visualize the confidence of an action being displayed in a colored box that is filled at 100% and is empty at 0%
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        # print((prob))
        cv2.rectangle(output_frame, (0,60+num*40), (120, 90+num*40), colors[num], 1)
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*120), 90+num*40), colors[num], -1) # .astype(np.int64)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
# Detection variables
sequence = []
prediction = ''
predictions = []
# We can use a high threshold since our network's accuracy is high
threshold = 0.8

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        img, results = mediapipe_detection(frame, holistic)
        # print(results)
        
        # Draw landmarks
        draw_landmarks(img, results)
        
        # Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        # Create a buffer with the last 30 frames so that we can input it to the model
        sequence = sequence[-30:]
        
        if len(sequence) == 30:     # Waiting for the frame count to reach 30
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            # print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    prediction = actions[np.argmax(res)]

            # Visualize probabilities in filling % of boxes
            img = prob_viz(res, actions, img, colors)

        # Show Predicted action    
        cv2.rectangle(img, (0,0), (640, 40), (245, 117, 16), -1)
        textsize = cv2.getTextSize(prediction, cv2.FONT_HERSHEY_SIMPLEX, 1, 2)[0]
        cv2.putText(img, prediction, (np.int((img.shape[1]- textsize[0])/2),30), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', img)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == 27:
            break
    cap.release()
    cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()
